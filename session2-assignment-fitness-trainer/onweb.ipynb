# %%
pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.6.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\thaku\anaconda3\lib\site-packages (from groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\thaku\anaconda3\lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\thaku\anaconda3\lib\site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\thaku\anaconda3\lib\site-packages (from groq) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\thaku\anaconda3\lib\site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\thaku\anaconda3\lib\site-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\thaku\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in c:\users\thaku\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\thaku\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\thaku\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\thaku\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\thaku\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\thaku\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.6.0-py3-none-any.whl (143 kB)
# Installing collected packages: groq
# Successfully installed groq-1.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from dotenv import load_dotenv
from groq import Groq

load_dotenv()

api_key = os.getenv("GROQ_API_KEY")
print(f"api_key={api_key}")
# Out:
# api_key=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

# %%
client = Groq()
model = os.getenv("GROQ_MODEL", "gpt-oss-20b")

# %%
completion = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "You are a fitness trainer."},
            {"role": "user", "content": f"""You are an experienced, certified personal trainer creating a real program for a client.
Use the information below the way a good trainer would — factor in their goal, experience,
schedule, equipment, and any limitations, and make sensible adjustments (exercise selection,
volume, intensity, progression) rather than giving generic advice.
 
CLIENT PROFILE
- Fitness goal: to muscle up
- Experience level: 2 years
- Days available per week: 3
- Equipment access: Enough
- Age range: 50 years
- Preferred session length: 60 minutes
- Priority focus areas: chest and biceps
- Injuries / limitations: none
 
INSTRUCTIONS
1. If there are injuries or limitations, explicitly note how you adapted the plan for them
   (e.g. substituted exercises, avoided certain movements).
2. Build a full weekly split matching the number of available days exactly — label each day
   with a name (e.g. "Day 1 - Upper Body Push") and rest days if applicable.
3. For each training day, list exercises with sets, reps (or duration), rest periods, and
   brief form/intensity cues. Match volume and intensity to the stated experience level.
4. Keep total time per session close to the client's preferred session length.
5. Add a short section at the top: "Why this plan" — 2-4 sentences explaining the overall
   approach and how it's tailored to this specific client.
6. Add a brief "Progression" note at the end explaining how to advance over the coming weeks.
7. Format everything in clean Markdown with headers per day and bullet/numbered lists for
   exercises, so it renders well in a Markdown viewer.
"""},
        ],
        temperature=0.8,
        max_tokens=100,
    )

response = completion.choices[0].message.content
if not response:
    print("LLM returned an empty response")

print(response.strip())
# Out:
# LLM returned an empty response

# %%
completion = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": "You are a fitness trainer."},
            {"role": "user", "content": f"Write one short, full body workout plan."},
        ],
        temperature=0.8,
        max_tokens=100,
    )

# %%
fitness_palan = completion.choices[0].message.content
if not fitness_palan:
    print("fitness_plan came back empty")
print(fitness_palan)
# Out:
# **Full‑Body “Power‑Pack” Workout**
# *(≈30 minutes, 3 days/week – e.g., Mon & Thu
